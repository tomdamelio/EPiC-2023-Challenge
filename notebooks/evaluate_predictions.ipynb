# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from helpers_scenario3 import *

# %%
def plot_valence_arousal(df, idx):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

    ax1.plot(df['time'], df['valence_pred'], label='Valence Predicted', linewidth=2, )
    ax1.plot(df['time'], df['valence'], label='Valence Original', linewidth=2, alpha = 0.5)
    
    ax1.set_title(f'Time Series {idx}: Valence')
    ax1.set_ylim([1,9])
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Value')
    ax1.legend()

    ax2.plot(df['time'], df['arousal_pred'], label='Arousal Predicted', linewidth=2, )
    ax2.plot(df['time'], df['arousal'], label='Arousal Original', linewidth=2,alpha = 0.5)
    ax2.set_title(f'Time Series {idx}: Arousal')
    ax2.set_xlabel('Time')
    ax2.set_ylim([1,9])
    ax2.legend()

    plt.show()

# %%
df_results = pd.read_csv('../results/scenario_1/results_knn3_pca3.csv')
df_results.describe()
# Out:
#           arousal     valence
# count  240.000000  240.000000
# mean     0.524413    0.516744
# std      0.600038    0.572286
# min      0.000000    0.000000
# 25%      0.099657    0.083117
# 50%      0.333792    0.340684
# 75%      0.706515    0.772342
# max      2.962520    3.908416

# %%
df_results = pd.read_csv('../results/scenario_1/results_knn5_pca3.csv')
df_results.describe()
# Out:
#           arousal     valence
# count  240.000000  240.000000
# mean     0.528718    0.519364
# std      0.607940    0.573596
# min      0.000000    0.000000
# 25%      0.098107    0.091989
# 50%      0.332363    0.326483
# 75%      0.739527    0.768206
# max      3.046460    3.911092

# %%
df_results = pd.read_csv('../results/scenario_3/results_rf.csv')
df_results.describe()
# Out:
#          arousal    valence
# count  30.000000  30.000000
# mean    0.752616   1.112059
# std     0.377432   0.574535
# min     0.085158   0.337473
# 25%     0.538832   0.702183
# 50%     0.645049   0.958177
# 75%     1.008106   1.525949
# max     1.825201   2.582760

# %%
df_results = pd.read_csv('../results/scenario_3/results_rf_knn.csv')
df_results.describe()
# Out:
#          arousal    valence
# count  30.000000  30.000000
# mean    1.070059   1.177385
# std     0.516329   0.573399
# min     0.069132   0.374531
# 25%     0.692310   0.696461
# 50%     0.953572   1.088350
# 75%     1.518943   1.477672
# max     2.029166   2.523911

# %%
path = '../results/test/scenario_2/fold_0/'
files = os.listdir(path)
for i, file in enumerate(files[20:40]):
    df = pd.read_csv(os.path.join(path, file))#.query('time > 70000')
    plot_valence_arousal(df, i+1)
